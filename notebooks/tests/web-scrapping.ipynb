# %%
import requests
from bs4 import BeautifulSoup
import re

# %%
url = 'https://www.megaboxatacado.com.br/'
response = requests.get(url)
html = response.text


main_page = BeautifulSoup(html, 'html.parser')

# %%
def get_headers_homepage(soup: BeautifulSoup) -> List:
  
	headers = soup.find_all('h1')
	headers_names = []

	for h in headers:
		headers_names.append(h.text.strip())

	return headers_names


def get_links_from_menus(soup: BeautifulSoup) -> List:
	megabox = 'https://www.megaboxatacado.com.br'

	divs_menu = soup.find('div', 'submenu_left')
	links = divs_menu.find_all('a', href = True)

	all_links_extracted = [l['href'] for l in links]
	links_ready = [f'{megabox}{l}' for l in all_links_extracted]

	return links_ready

def get_labels_products(links: list):
	
	data = {}

	for link in links:
		response = requests.get(link)
		html = response.text
		page = BeautifulSoup(html, 'html.parser')
		labels = page.find('div', 'content_select_list').find_all('label')

		extract_brand_class = re.search(r"/([^/]+)/ss", link)

		if extract_brand_class:
			brand_class = extract_brand_class.group(1)

		brands = []

		for brand in labels:
			pattern = r"^(.*?)\s*\(\d+\s*ítens\)"

			result = re.search(pattern, brand.getText())
			if result:
				brand_treated = result.group(1).strip()
				brands.append(brand_treated)

		data[brand_class] = brands
		
	return data

# %%
links = get_links_from_menus(main_page)

# %%
response = requests.get(links[0])
html = response.text

categories_page = BeautifulSoup(html, 'html.parser')

# %%
marca = categories_page.find('div', 'content_select_list').find_all('label')

# %%
marca[0].getText()
# Out:
# 'Granfino (4 ítens)'

# %%
pattern = r"^(.*?)\s*\(\d+\s*ítens\)"

result = re.search(pattern, marca[0].getText())
brand = result.group(1).strip()

# %%
result.group(1).strip()
# Out:
# 'Granfino'

# %%
r = get_labels_products(links)

# %%
len(r)
# Out:
# 42

# %%
r.keys()
# Out:
# dict_keys(['arroz', 'feijao', 'cafe', 'cereais-naturais-e-matinais', 'farinhas-e-feculas', 'graos-diversos', 'pipoca', 'massas-frescas', 'massas-secas', 'massas-instantaneas', 'chocolates-em-barra-e-bombons', 'chocolates-importados-e-especiais', 'balas-gomas-e-confeitos', 'doces-cremosos-e-de-corte', 'frutas-em-calda-e-compotas', 'fondue-e-cobertura', 'geleias', 'mel-e-caldas', 'ingredientes-culinarios', 'preparos-para-sobremesa', 'acucares-e-adocantes', 'conservas', 'pastas-e-pates', 'antepastos', 'biscoitos-doces', 'biscoitos-salgados', 'cookies', 'snacks', 'barras-de-cereal-nuts-e-energeticas', 'ervas-e-especiarias', 'cogumelos-e-trufas', 'extratos-e-polpas', 'molhos', 'azeites', 'oleos-culinarios', 'sal', 'vinagres', 'temperos-prontos', 'aves', 'salgadas-e-defumadas', 'sopas-e-cremes', 'papinhas'])

# %%
r['fondue-e-cobertura']
# Out:
# []

# %%
# Out:
# {'arroz': ['Granfino', 'Korin', 'Riso Scotti', 'Tio João', 'Tio Mingote'],
#  'feijao': ['Combrasil', 'Granfino'],
#  'cafe': ['3 Corações',
#   'Caffé Vergnano',
#   "L'or",
#   'Me Bebe',
#   'Melitta',
#   'Native',
#   'Nescafé',
#   'Orfeu',
#   'Pilão',
#   'Tassinari',
#   'TRES'],
#  'cereais-naturais-e-matinais': ['Arma Zen', 'Jasmine', 'Kellogg s', 'Native'],
#  'farinhas-e-feculas': ['Arma Zen',
#   'Dona Benta',
#   'Granfino',
#   'Renata',
#   'Rosa Branca',
#   'Tipity',
#   'Yoki'],
#  'graos-diversos': ['Granfino'],
#  'pipoca': ['Yoki'],
#  'massas-frescas': ['Carneiro', 'Massa Leve'],
#  'massas-secas': ['De Cecco',
#   'Delverde',
#   'Farabella',
#   'Gallo',
#   'Piraquê',
#   'Renata',
#   'Selmi',
#   'Urbano'],
#  'massas-instantaneas': ['Nissin'],
#  'chocolates-em-barra-e-bombons': ['Bis',
#   'Ferrero',
#   'Hamlet',
#   'Kinder Bueno',
#   'Kinder Ovo',
#   'Kit Kat',
#   'Talento',
#   'Twix'],
#  'chocolates-importados-e-especiais': ['Lindt', 'Nugali'],
#  'balas-gomas-e-confeitos': ['Fini', 'Mentos', 'Tic Tac'],
#  'doces-cremosos-e-de-corte': ['Airon',
#   'Nutella',
#   'Predilecta',
#   'Santa Helena Paçoquita',
#   'Tachão de Ubatuba',
#   'Viçosa'],
#  'frutas-em-calda-e-compotas': [],
#  'fondue-e-cobertura': [],
#  'geleias': ['Ducopo',
#   'Frutt`Oro',
#   'Prima Frutta',
#   'Queensberry',
#   'St Dalfour'],
#  'mel-e-caldas': ['Amigos da Terra', 'Vale das Palmeiras'],
#  'ingredientes-culinarios': ['Copra', 'Dr. Oetker', 'Nestlé', 'Sococo'],
#  'preparos-para-sobremesa': ['Dr. Oetker',
#   'Itambé',
#   'Piracanjuba',
#   'Royal',
#   'Zélia'],
#  'acucares-e-adocantes': ['Linea', 'Native', 'União'],
#  'conservas': ['Bonduelle',
#   'Coqueiro',
#   'Gomes da Costa',
#   'Iliada',
#   'Muraca',
#   'Quero',
#   'Saborosas'],
#  'pastas-e-pates': ['Gomes da Costa', 'Sadia'],
#  'antepastos': [],
#  'biscoitos-doces': ['Aruba',
#   'Bauducco',
#   'Belvita',
#   'Bom Biscoito',
#   'Helgas Brot',
#   'Kodilar',
#   'Mulino Bianco',
#   'Nestlé Passatempo',
#   'Oreo',
#   'Vicenzi'],
#  'biscoitos-salgados': ['Bom Biscoito',
#   'Club Social',
#   'Eqlibri',
#   'Goodsoy',
#   'Piraquê',
#   'Vale D Ouro'],
#  'cookies': ['Jasmine'],
#  'snacks': ['Palomithas', 'Yoki'],
#  'barras-de-cereal-nuts-e-energeticas': [],
#  'ervas-e-especiarias': ['Kotanyi'],
#  'cogumelos-e-trufas': [],
#  'extratos-e-polpas': [],
#  'molhos': ['Cepêra',
#   'De Cecco',
#   'Heinz',
#   'Hellmanns',
#   'Hemmer',
#   'Kenko',
#   'Kitano',
#   'Moça Terra',
#   'NotCo',
#   'Pomarola',
#   'Pramesa',
#   'Sakura',
#   'Tempemar'],
#  'azeites': ['Andorinha'],
#  'oleos-culinarios': ['Copra', 'Liza', 'Peixe', 'Soya'],
#  'sal': ['Cisne', 'Ita'],
#  'vinagres': ['De Nigris', 'Peixe', 'Rosani'],
#  'temperos-prontos': ['Aji no moto',
#   'Arisco',
#   'Knorr',
#   'Maggi',
#   'Sabor Ami',
#   'Sazón'],
#  'aves': [],
#  'salgadas-e-defumadas': [],
#  'sopas-e-cremes': ['Ferrer', 'Maggi', 'Vono'],
#  'papinhas': []}
