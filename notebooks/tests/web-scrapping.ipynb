# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.megaboxatacado.com.br/'
response = requests.get(url)
html = response.text


soup = BeautifulSoup(html, 'html.parser')

# %%
headers = soup.find_all('h1')

# %%
headers
# Out:
# [<h1>Ofertas</h1>,
#  <h1>Mercearia &amp; Gastronomia</h1>,
#  <h1>Matinais</h1>,
#  <h1>Pães &amp; Bolos</h1>,
#  <h1>Bebidas</h1>,
#  <h1>Vinhos</h1>,
#  <h1>Higiene &amp; Beleza</h1>,
#  <h1>Limpeza</h1>,
#  <h1>Alimentação Saudável</h1>,
#  <h1>Mais Categorias</h1>]
